# %%
## Trying different feature extraction methods from sckitlearn and see if can be applied to HW4
## More note can be found in the trial and test note.docx

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

import pandas as pd
import numpy as np


# Initialize the "TfidVectorizer" object, which is scikit-learn's
# bag of words tool. http://scikit-learn.org/dev/modules/feature_extraction.html#text-feature-extraction
vectorizer = TfidfVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000)


## Initialize n-gram vectorizer
# ngram_vectorizer = CountVectorizer(analyzer='char_wb', ngram_range=(2, 2), min_df=1)
ngram_vectorizer = CountVectorizer(ngram_range=(4, 4),token_pattern=r'\b\w+\b', min_df=1, max_features = 5000)


## These following two tools are also initialized, but can't be used report dtype error
## TO-DO: need to fix it
transformer = TfidfTransformer()
hashvect = HashingVectorizer()

#import file
df = pd.read_csv('Data/all_plays_tokenized.txt',sep='\t')

# Get all the play names
playnames = pd.unique(df.playname.ravel())

# Array to hold bag of words for each play
play_bagwords = []
act_bagwords = []
scene_bagwords = []
# Arrays to hold labels
play_label = []
act_label = []
scene_label = []
# Array to hold genres
play_genre = []
act_genre = []
scene_genre = []

# Vectorizer results are normalized, which makes KMeans behave as
# spherical k-means for better results. Since LSA/SVD results are
# not normalized, we have to redo the normalization.
# svd = TruncatedSVD()
# normalizer = Normalizer(copy=False)
# lsa = make_pipeline(svd, normalizer)

## loop through all plays
for i in range(len(playnames)):
    
    ### Create bag of words for all plays
    p = df[df['playname'] == playnames[i]] # Get the sub data frame of each play
    s = "" # Initiate empty string to hold bag of words for play
    genre = p['genre'].unique()
    genre = str(genre)
    play_genre.append(genre)
    # Iterate all the rows to append the speech and speaker words to a string
    for index,row in p.iterrows():
        s += str(row['speaker'])
        s += str(row['speech'])

    # Append the bag of words to each play
    play_bagwords.append(s)
    # Append the label to each row
    play_label.append(str(playnames[i]))
    
    ### Create bag of words for all the acts in each play
    s = "" # Initiate empty string to hold bag of words for acts
    acts = pd.unique(p.act.ravel()) # Get the number of acts and scenes
    
    for j in range(len(acts)):
        
        a = p[p['act'] == acts[j]] #Get the current act
        # Array to hold bag of words for each bag
#         act_bagwords = []
         # Iterate all the rows to append the speech and speaker words to a string
        for index,row in a.iterrows():
            s += str(row['speaker'])
            s += str(row['speech'])

        # Append the bag of words to each act within the play
 
        act_bagwords.append(s) 
        act_label.append(str(playnames[i]) +'_'+ str(acts[j]))
        act_genre.append(genre)
        s = ""
  
        scenes = pd.unique(a.scene.ravel()) # Get the number of acts and scenes
        # Array to hold bag of words for each scene
#         scene_bagwords = []
        for z in range(len(scenes)):
        
            sc = a[a['scene'] == scenes[z]] #Get the current act
        
             # Iterate all the rows to append the speech and speaker words to a string
            for index,row in sc.iterrows():
                s += str(row['speaker'])
                s += str(row['speech'])

                
            # Append the bag of words to each act within the play
            scene_bagwords.append(s)  
            scene_label.append(str(playnames[i]) +'_'+ str(acts[j]) +'_'+ str(scenes[z]))
            scene_genre.append(genre)
# f = open("scene_feature_labels.txt", "w")
# f.write("\n".join(map(lambda x: str(x), scene_label)))
# f.close()
# f = open("act_feature_labels.txt", "w")
# f.write("\n".join(map(lambda x: str(x), act_label)))
# f.close()
# f = open("play_feature_labels.txt", "w")
# f.write("\n".join(map(lambda x: str(x), play_label)))
# f.close()

#     #Vectorize analyze the similarities among plays
#     act_vect = vectorizer.fit_transform(act_bagwords)
#     scene_vect = vectorizer.fit_transform(scene_bagwords)
    act_ngram = ngram_vectorizer.fit_transform(act_bagwords)
    scene_ngram = ngram_vectorizer.fit_transform(scene_bagwords)
    act_ngram = act_ngram.toarray() # Show the similarity array of plays
    scene_ngram = scene_ngram.toarray() # Show the similarity array of plays
    
    #analyze = vectorizer.build_analyzer()
#     act_feature = act_vect.toarray() # Show the similarity array of plays
#     scene_feature = scene_vect.toarray() # Show the similarity array of plays
#     act_feature = lsa.fit_transform(act_vect) # Apply Latent Semantic Analysis
#     scene_feature = lsa.fit_transform(scene_vect) # Apply Latent Semantic Analysis
#     Write the scene and act feature array to text files for each play
#     fn1 = str(playnames[i])+"_Act_Features_Vectorize_LSA.txt"
#     fn2 = str(playnames[i])+"_Scene_Features_Vectorize_LSA.txt"
#     np.savetxt(fn1, act_feature, delimiter=",")
#     np.savetxt(fn2, scene_feature, delimiter=",")
#     np.savetxt("Act_Features_Vectorize_LSA.txt", act_feature, delimiter=",")
#     np.savetxt("scene_Features_Vectorize_LSA.txt", scene_feature, delimiter=",")
#     np.savetxt("Act_Features_ngram4.txt", act_ngram, delimiter=",")
#     np.savetxt("Scene_Features_ngram4.txt", scene_ngram, delimiter=",")
#     explained_variance = svd.explained_variance_ratio_.sum()
#     print(explained_variance)


# Vectorize analyze the similarities among plays
# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
# play_vect = vectorizer.fit_transform(play_bagwords)
play_ngram2= ngram_vectorizer.fit_transform(play_bagwords)
play_ngram2 = play_ngram2.toarray() 
# play_ngram= ngram_vectorizer.fit_transform(play_bagwords)
# play_ngram = play_ngram.toarray() 
# #analyze = vectorizer.build_analyzer()

# # Numpy arrays are easy to work with, so convert the result to an 
# # array
# play_feature = play_vect.toarray() # Show the similarity array of plays

# play_feature = lsa.fit_transform(play_feature) # Apply Latent Semantic Analysis


# explained_variance = svd.explained_variance_ratio_.sum()
# print(explained_variance)


# See the data arrary: print (play_feature.shape)

# Write the plays feature array to a csv file
# np.savetxt("Play_Features_Vectorize.txt", play_feature, delimiter=",")
# np.savetxt("Play_Features_ngram.txt", play_ngram, delimiter=",")
# np.savetxt("Play_Features_ngram4.txt", play_ngram2, delimiter=",")
# np.savetxt("Play_Features_Vectorize_LSA.txt", play_feature, delimiter=",")

# Take a look at the words in the vocabulary
# vocab = vectorizer.get_feature_names()

# import numpy as np
# print(vocab)

### Print the count of each word in vocab -- not working somehow
# # Sum up the counts of each vocabulary word
# dist = np.sum(play_feature, axis=0)
# # For each, print the vocabulary word and the number of times it 
# # appears in the training set
# for tag, count in zip(vocab, dist):
#     print (count, tag)



#Y = transformer.fit_transform(play_bagwords) -- To DO fix the error: no supported conversion for types: (dtype('<U98727')

# %%
# print(act_genre,play_genre,scene_genre)
# np.savetxt("Play_genres.txt", play_genre, delimiter=",")
# np.savetxt("Act_genres.txt", act_genre, delimiter=",")
# np.savetxt("Scene_genres.txt", scene_genre, delimiter=",")
f = open("t2.txt", "w")
f.write("\n".join(map(lambda x: str(x), scene_genre)))
# print(p['genre'].unique())
# Out:
# 3007

# %%
ngram_vectorizer.get_feature_names()
# Out:
# ['1 live flourish trumpet',
#  'air state cedar shall',
#  'almighti gave hector gift',
#  'ambiti brutu honour man',
#  'among nine bad one',
#  'ancestor greatest obloquy world',
#  'ann wife sick like',
#  'ape humbl bee still',
#  'argument state put thyself',
#  'arrest thee high treason',
#  'art made thou desirest',
#  'art tall fellow thi',
#  'art think thou art',
#  'art thou thou art',
#  'asid doctor caiu pray',
#  'asid domitiu enobarbu meandomitius',
#  'asid high blood royalti',
#  'asid o sweet ann',
#  'ass fool prate coxcomb',
#  'banish thee pain death',
#  'banish thi harri compani',
#  'battl think fall thi',
#  'bequeath mani ancestor greatest',
#  'bid prepar dinnerlauncelotdone sir',
#  'bid thee despair die',
#  'birnam wood come dunsinan',
#  'blood love flesh blood',
#  'blunt bear good night',
#  'bolingbrokegood aunt standduchess of',
#  'bolingbrokethank thee gentl perci',
#  'box o th ear',
#  'brag came saw overcam',
#  'branch dead mani year',
#  'breath awhil thou hast',
#  'britain fortun flourish peac',
#  'brutu say ambiti brutu',
#  'brutu thou sleepst awak',
#  'call thee thou art',
#  'captain blunt bear good',
#  'cast thi humbl slough',
#  'castl safer shall upon',
#  'cedar shall lop branch',
#  'charl delabreth high constabl',
#  'charl great subdu saxon',
#  'chief justic tsir john',
#  'chief justic twell god',
#  'chooseth must give hazard',
#  'chooseth shall gain mani',
#  'chooseth shall get much',
#  'cold news hope franc',
#  'come come give hand',
#  'come go us well',
#  'come hither come hither',
#  'come hither shall see',
#  'come home come home',
#  'come let us go',
#  'come tailor let us',
#  'commend thi yellow stock',
#  'comment appelez vou le',
#  'content respect love bear',
#  'court parliament let us',
#  'cri mum cri budget',
#  'cuckoo cuckoo o word',
#  'cuckoo everi tree mock',
#  'cuckoo o word fear',
#  'cup us till world',
#  'davi let see davi',
#  'day o day o',
#  'day sinc saw princ',
#  'de elbow de nick',
#  'de fingr de nail',
#  'de hand de fingr',
#  'dead mani year shall',
#  'deaf lord chief justic',
#  'delabreth high constabl franc',
#  'depos outliv die violent',
#  'deserv well hand help',
#  'desir acquaint good master',
#  'devic bear upon shield',
#  'didst thou ever know',
#  'domitiu enobarbu meandomitius enobarbus',
#  'done wrong therefor ill',
#  'dost thou think ill',
#  'doth horn moon present',
#  'doubl toil troubl fire',
#  'duke clarenc third son',
#  'duke york right heir',
#  'east west north south',
#  'edgeless sword despair die',
#  'edmund langley duke york',
#  'edmund mortim earl march',
#  'edward ivwarwick wilt thou',
#  'edward thi suppos king',
#  'edward till richard killd',
#  'embrac piec tender air',
#  'end miseri britain fortun',
#  'enobarbu meandomitius enobarbus asid',
#  'evans asid doctor caiu',
#  'eve night shall fourteen',
#  'everi tree mock marri',
#  'evil give leav circumst',
#  'face thou wilt fall',
#  'fall thi edgeless sword',
#  'fals edward thi suppos',
#  'fare thee well thou',
#  'father devic bear upon',
#  'fear unpleas marri ear',
#  'fellow thi hand thou',
#  'find embrac piec tender',
#  'find person whose name',
#  'fingr de nail de',
#  'fire burn cauldron bubblsecond',
#  'five hundr pound year',
#  'flesh blood love flesh',
#  'fortun flourish peac plenti',
#  'foul sin gather head',
#  'fox ape humbl bee',
#  'franc send masquer revel',
#  'freshli grow shall posthumu',
#  'front heaven full fieri',
#  'gain mani men desir',
#  'gentlemen go muster men',
#  'get thee gone see',
#  'get thee sight thou',
#  'give cup sack rogu',
#  'give hazard hath shall',
#  'give thee thi due',
#  'go bid thi master',
#  'go play boy play',
#  'go say sent thee',
#  'go thi cold bed',
#  'go thi way old',
#  'god give good rest',
#  'god plagu thee thou',
#  'god sake let us',
#  'good angel guard thee',
#  'good captain blunt bear',
#  'good master robert shallow',
#  'good night good night',
#  'grace regent part franc',
#  'grandpr roussi fauconberg foix',
#  'grant woman withal woman',
#  'greasi joan doth keel',
#  'great achiev great great',
#  'grow shall posthumu end',
#  'hadst feard break oath',
#  'hand de fingr de',
#  'hand thou wilt drunk',
#  'hang upon mine eye',
#  'harri perci spur cold',
#  'hast love thou hast',
#  'hath done wrong therefor',
#  'hath made peac rome',
#  'hath made thee faint',
#  'hawthorn blow cold wind',
#  'he dead he dead',
#  'heart love heart cannot',
#  'heart love heart love',
#  'heaven full fieri shape',
#  'heavi thi soul morrow',
#  'hell prove widow shortli',
#  'help help ho help',
#  'henri shall depos outliv',
#  'hey ho hey nonino',
#  'hic est sigeia tellu',
#  'hither come hither come',
#  'hither come hither shall',
#  'hither shall see enemi',
#  'ho lieuten sir montano',
#  'hold here gold thee',
#  'honour pawn engag trial',
#  'hope hell prove widow',
#  'hors yet would never',
#  'hous bequeath mani ancestor',
#  'hugh evans asid doctor',
#  'humbl bee still odd',
#  'iii let sit heavi',
#  'ill tell thee friend',
#  'ill wear willow garland',
#  'instanc o instanc strong',
#  'ivlord give us leav',
#  'joan doth keel pot',
#  'john de la car',
#  'john hath made peac',
#  'john know sir john',
#  'joint old stock freshli',
#  'kill kill kill kill',
#  'king lewi franc send',
#  'king nine month old',
#  'king richard iii let',
#  'king richard iii think',
#  'kingking henry vi asid',
#  'kinsman surli servant let',
#  'knock knock knock who',
#  'know man athenian garment',
#  'know thee well enough',
#  'know thou didst hate',
#  'lamma eve night shall',
#  'lanc almighti gave hector',
#  'let look bond wont',
#  'let see davi let',
#  'let see let see',
#  'let see writeduke of',
#  'let see yea marri',
#  'let sit heavi thi',
#  'let thi tongu tang',
#  'let us hear speak',
#  'lewi franc send masquer',
#  'lie direct may avoid',
#  'lion whelp shall unknown',
#  'lionel duke clarenc third',
#  'live henri shall depos',
#  'long mayst thou live',
#  'lop branch dead mani',
#  'lord chief justic thow',
#  'lord chief justic ti',
#  'lord chief justic tnow',
#  'lord chief justic tsir',
#  'lord chief justic twell',
#  'lord chief justic twhat',
#  'lord chief justic tyou',
#  'lord lord chief justic',
#  'lord northumberland say king',
#  'lorenzo fare ye well',
#  'lose thi master lose',
#  'lose thi voyag lose',
#  'love heart love heart',
#  'love lord chief justic',
#  'love thee thou art',
#  'luciliu servant tfive thousand',
#  'lullabi lulla lulla lullabi',
#  'macbeth hail thee thane',
#  'main shall releas deliv',
#  'make believ thou art',
#  'mani ancestor greatest obloquy',
#  'mani men desir mani',
#  'mani mile tread measur',
#  'mani year shall reviv',
#  'mar lanc almighti gave',
#  'marri men thu sing',
#  'master brook master brook',
#  'master doctor caiu come',
#  'meandomitius enobarbus asid cleopatra',
#  'measur mani mile tread',
#  'melodi bird sing madrig',
#  'men neer sit wail',
#  'men thu sing tcuckoo',
#  'merri note greasi joan',
#  'might live see thee',
#  'mine host de jarteer',
#  'miseri britain fortun flourish',
#  'mistress ford mistress ford',
#  'mock marri men thu',
#  'morrow battl think fall',
#  'must give hazard hath',
#  'nail de arm de',
#  'nathanielworld live world command',
#  'never merri world sinc',
#  'never never never never',
#  'never sawest good manner',
#  'news lord lord chief',
#  'nightli sing stare owl',
#  'nine bad one good',
#  'note greasi joan doth',
#  'number ave mari bead',
#  'nurs news hast thou',
#  'o day o day',
#  'o pit clay made',
#  'o wall o sweet',
#  'o word fear unpleas',
#  'oh oh ha ha',
#  'old ling isbel o',
#  'old sir robert son',
#  'old stock freshli grow',
#  'opposit kinsman surli servant',
#  'owl ttu whit tu',
#  'pain found fals recreant',
#  'pari saint peter church',
#  'part ill meddl make',
#  'paus take thi breath',
#  'pawn engag trial thou',
#  'payment hundr thousand crown',
#  'piec tender air state',
#  'pit clay made guest',
#  'plain castl mount stand',
#  'posthumu end miseri britain',
#  'present unto highking henry',
#  'princ baron lord knight',
#  'promis ill good word',
#  'prove widow shortli ill',
#  'proverb verb give thi',
#  'proverb well effect staff',
#  'proverb well part master',
#  'proverbd grandsir phrase ill',
#  'proveth edward love warwick',
#  'proveth wellking edward ivyea',
#  'provethomas mowbraylet cold word',
#  'provexit apexsimonidesfourththaisaburn torch that',
#  'provid abllordking queen comehamlethappi',
#  'provid banish repeald land',
#  'provid banishd till convers',
#  'provid better time come',
#  'provid block axe morrow',
#  'provid bottom must done',
#  'provid cart bring away',
#  'provid casetheseussay hermia advis',
#  'provid cater sparrow comfort',
#  'provid chain ill get',
#  'provid charm everi thing',
#  'provid commend free entertainposthumus',
#  'provid dispatch present hour',
#  'provid els would day',
#  'provid execution tender safeti',
#  'provid fall sparrow ti',
#  'provid favour present becom',
#  'provid fear may teach',
#  'provid feast father bid',
#  'provid fit welcom give',
#  'provid fortun achiev mistressportiatrue',
#  'provid gearcalchasprinc servic done',
#  'provid gentleman nobl parentag',
#  'provid give great gift',
#  'provid go choos compani',
#  'provid go put hastcharmianmadamdolabellaqueencharmianbehold',
#  'provid half dozen suffici',
#  'provid he remov high',
#  'provid high power govern',
#  'provid holi angel fli',
#  'provid kept short restraind',
#  'provid ladinorthumberlando fli scotland',
#  'provid ladyship behold hear',
#  'provid messeng heart heavi',
#  'provid munit sent underprop',
#  'provid musicantoniobusi brother tell',
#  'provid must person satir',
#  'provid none companion maid',
#  'provid outrag silli women',
#  'provid outstay time upon',
#  'provid peril bind courag',
#  'provid pierc statut daili',
#  'provid pleas deliber day',
#  'provid present ride suit',
#  'provid princ worlddauphinlong night',
#  'provid salv sore may',
#  'provid see coron performdgloucesterbrave',
#  'provid shall much help',
#  'provid shall put night',
#  'provid she mine chose',
#  'provid show entertainflavius asid',
#  'provid soldier lord while',
#  'provid stay awhil shall',
#  'provid storm one twin',
#  'provid that watch state',
#  'provid thee two proper',
#  'provid theeclarencechoos showd judgment',
#  'provid thi money morrow',
#  'provid thine futur safeticromwello',
#  'provid thou shalt best',
#  'provid torch bearersalanioay marri',
#  'provid us goodcleomenessir done',
#  'provid us thing necessari',
#  'provid weed better judgment',
#  'provid wit reason mitig',
#  'providburgundytrust ghost talbot gone',
#  'providcranmerah good lord winchest',
#  'providfirst senatorlord voic fault',
#  'providguideriusmoney youtharviragusgold silver rather',
#  'providparollesgood monsieur lavach give',
#  'provinc arm mine conquer',
#  'provinc contin sparrow must',
#  'provinc give thee make',
#  'provinc region love love',
#  'provinc thee addit full',
#  'provinc thou hast misspok',
#  'provinc yet let entreat',
#  'provincalenconever expuls franc titl',
#  'provincdomitius enobarbusappear fightscarusside like',
#  'provinci busi state made',
#  'provinci rose raze shoe',
#  'provincwarwicktalk franc sith thou',
#  'provis follow soon safe',
#  'provis give thee quick',
#  'provis intent needlysimachussir heart',
#  'provis mine art safe',
#  'provis shall need entertainking',
#  'provis shield thee diseas',
#  'provis ti near nightcapulettush',
#  'provis wherein destitut want',
#  'provisfirst lordsick grief understand',
#  'proviso except charg shall',
#  'provoc sheltermistress fordmistress page',
#  'provoccassioinvit eye yet methink',
#  'provok battl till done',
#  'provok cannot great danger',
#  'provok delug unnatur o',
#  'provok desir take away',
#  'provok first took except',
#  'provok franc would abat',
#  'provok good lord offend',
#  'provok harm pray tell',
#  'provok hasti send someth',
#  'provok instig distemp forsooth',
#  'provok king cut head',
#  'provok languag would make',
#  'provok like current fli',
#  'provok mani simpl oper',
#  'provok may even caus',
#  'provok merit set work',
#  'provok mightiest hulk tide',
#  'provok murder near lust',
#  'provok nay dispatch twa',
#  'provok offencmark antonyone word',
#  'provok pleas pay duti',
#  'provok provok soon calmd',
#  'provok queen devis impeach',
#  'provok question dear durst',
#  'provok rage ire albeit',
#  'provok ridicul smile o',
#  'provok shall notori lord',
#  'provok soon calmd heart',
#  'provok suitor els aim',
#  'provok term honour littl',
#  'provok thee boypageo lord',
#  'provok thi bloodi mind',
#  'provok thi wrath sorri',
#  'provok three thingmacduffthree thing',
#  'provok threefold perjuri love',
#  'provok unprovok provok desir',
#  'provok us hither slaughter',
#  'provok virtu eye must',
#  'provok wil disobedi rebel',
#  'provokcadenay nod us say',
#  'provokest thyself cast thou',
#  'provokest yet grossli fearst',
#  'provoketh thiev sooner goldceliaill',
#  'provokking johncurs king attend',
#  'provokportermarri sir nose paint',
#  'provokprosperoauster punishd compens make',
#  'provost away prison lay',
#  'provost brother angelo alter',
#  'provost calld lateprovostnone sinc',
#  'provost came claudio behead',
#  'provost hath warrant executisabellaala',
#  'provost honesti constanc read',
#  'provost know place abid',
#  'provost know purpos plot',
#  'provost let bail gentl',
#  'provost prison there madam',
#  'provost round citi woman',
#  'provost seldom steel gaoler',
#  'provost shall bear whose',
#  'provost shall hear ere',
#  'provost stay sir stay',
#  'provost thinkprovostprovost what good',
#  'provost wordprovostwhat fatherduke vincentiocome',
#  'provostduke vincentiowithin sirlucioo pretti',
#  'provostescalusgood time speak till',
#  'provostescaluslord amaz dishonour strangduke',
#  'provostprovostclaudio shall die tomorrowangelotell',
#  'prowess confirmd unshrink station',
#  'prowess conquer franc henri',
#  'prowess want prais esteem',
#  'prudenc smatter gossip gonursespeak',
#  'prudenc upbraid cours rest',
#  'prudent disciplin north south',
#  'prudent excel unmatchd wit',
#  'prudent help poison diseas',
#  'prudent would quickli gift',
#  'prune bristl crest youth',
#  'prune dri cake captain',
#  'prune frothay indepompeywell tell',
#  'prune immort wing cloy',
#  'prune intrus infect thi',
#  'prune mani raisin o',
#  'prune shall hear prais',
#  'prune sir two hous',
#  'prune troth cannot abid',
#  'prune truth thee drawn',
#  'prune two dish said',
#  'prunest rotten tree cannot',
#  'pryd crevic wall hand',
#  'ps contempt question handsir',
#  'psalm horn pipe must',
#  'psalm thing plagu coward',
#  'psalm tune green sleev',
#  'psalmist saith certain shall',
#  'psalteri fife tabour cymbal',
#  'ptolemi assignd syria cilicia',
#  'ptolemi give kingdom mirth',
#  'ptolemi heir hazard thi',
#  'ptolemi pyramis goodli thing',
#  'ptolemi womanli hardli gave',
#  'public accus uncov slander',
#  'public benefit receiv proce',
#  'public bodi doth seldom',
#  'public busi rais usantigonus',
#  'public chair well hear',
#  'public common make forg',
#  'public count might go',
#  'public court twenti mile',
#  'public ear professd contrari',
#  'public ear spoke scantli',
#  'public good bridl suppress',
#  'public haunt find tongu',
#  'public haunt men either',
#  'public hors whereon governor',
#  'public law heaviest answerbothti',
#  'public leav speak neither',
#  'public make strain achil',
#  'public may without contradict',
#  'public minist justic hire',
#  'public peac pray heaven',
#  'public power set noughtfirst',
#  'public reason shall render',
#  'public shame rest court',
#  'public spectacl said terror',
#  'public sport appoint meet',
#  'public street gaze christian',
#  'public street lost breath',
#  'public thank forerun requitangelomake',
#  'public treasuribuckinghamthi cruelti execut',
#  'public war privat treason',
#  'public weal obey charg',
#  'public wealcharlesmar true move',
#  'public wrong sustaind franc',
#  'publican look hate christian',
#  'publicli enthron feet sat',
#  'publicli friend pay sum',
#  'publicli ill desir meet',
#  'publicli offencangelosee come behold',
#  'publicli read side author',
#  'publicli shame methink would',
#  'publicli shamemistress pagecome forg',
#  'publicli shell ashamescalusgo darkli',
#  'publicli take quarrel power',
#  'publicola caeliu sea keep',
#  'publicola moon rome chast',
#  'publish bore mind envi',
#  'publish commenddukehear learnd bellario',
#  'publish daughter sever dower',
#  'publish dead inde maintain',
#  'publish occas arm commonwealth',
#  'publish pretencdukeupon mine honour',
#  'publish truth sith yet',
#  'publish unless said mind',
#  'publishcountessknave get gone sirrah',
#  'publishd coron katharin shall',
#  'publishd gentl lord scarc',
#  'publishd proclaimd openli ti',
#  'publishd traitor henc lest',
#  'publishsuffolkill call present nobl',
#  'publiu brutu stirrd earli',
#  'publiu caiu valentin lay',
#  'publiu cimber may immedi',
#  'publiu cimbercassiuscould well move',
#  'publiu come fetchpubliusgood morrow',
#  'publiu come hither caiu',
#  'publiu fie thou art',
#  'publiu followsaturninuslord wrong ever',
#  'publiu good cheer harm',
#  'publiu hast thou done',
#  'publiu heavi case see',
#  'publiu lest peopl rush',
#  'publiu publiu hast thou',
#  'publiu quintu beat water',
#  'publiu semproniu must ti',
#  'publiu shall live sister',
#  'publiu shot bull galld',
#  'publiucassiusleav us publiu lest',
#  'publiucinnaquit confound mutinimetellus cimberstand',
#  'pucel enchant thi wordjoan',
#  'pucel enterd orlean spite',
#  'pucel hath performd wordcharlesdivinest',
#  'pucel hold thi peac',
#  'pucel joind holi prophetess',
#  'pucel practis specifi best',
#  'pucel puzzel dolphin dogfish',
#  'pucel term puretalbotmaid saybedfordmaid',
#  'pucel thi name let',
#  'pucel think old familiar',
#  'pucel witch damn sorceress',
#  'pucelle asid done like',
#  'pucelleadvanc wave colour wall',
#  'pucelleassignd english scourg night',
#  'pucelleaway captain let get',
#  'pucellebase passion fear accurs',
#  'pucellebehold happi wed torch',
#  'pucellebelik lordship take us',
#  'pucellebesid french franc exclaim',
#  'pucellebrave burgundi undoubt hope',
#  'pucellechang worser shape thou',
#  'pucellechrist mother help els',
#  'pucelleciti gate gate rouen',
#  'pucellecome come ti must',
#  'pucelledauphin birth shepherd daughter',
#  'pucelledeceiv child none alencon',
#  'pucelledecrepit miser base ignobl',
#  'pucelledismay princ accid griev',
#  'pucelleencounterd thu said thou',
#  'pucellefirst let tell condemnd',
#  'pucellegood grey beard break',
#  'pucellegood morrow gallant want',
#  'pucellehonour shall perceiv work',
#  'pucellelead henc leav curs',
#  'pucellelive ill neer fli',
#  'pucellelook thi countri look',
#  'pucellemust yield rite love',
#  'pucellenoth turn unrel heart',
#  'pucelleo give leav delud',
#  'pucellepaysan pauvr gen de',
#  'pucellepeac amongst turn us',
#  'pucellepeasant avaunt subornd man',
#  'pucelleplagu mischief light charl',
#  'pucelleprepar keen edg sword',
#  'pucelleprinc charl franc thi',
#  'pucelleprithe give leav curs',
#  'pucellequestion lord case way',
#  'pucelleregent conquer frenchmen fli',
#  'pucellereignier ist thou thinkest',
#  'pucellerouen ill shake thi',
#  'pucellesay distrust recreant fight',
#  'pucellesilli state style inde',
#  'pucelletalbot farewel thi hour',
#  'pucellethink upstart old talbot',
#  'pucellethu must doth joan',
#  'pucellewherefor charl impati friend',
#  'pucelleye hot sir yet',
#  'puck come hither thou',
#  'puck take transform scalp',
#  'puck work shall good',
#  'pud bag flaxmistress pagepuf',
#  'pud belli reverend vice',
#  'pud didst thou see',
#  'pud flap jack thou',
#  'pud hath stolen otherwis',
#  'pud master forthlight tilter',
#  'pud one day king',
#  'pud skincountesssay answer fit',
#  'puddl beast would cough',
#  'puddl clear spirit case',
#  'puddl mire quench hair',
#  'puddl sink whose filth',
#  'pudmistress fordmistress page trust',
#  'pueritia horn admothba silli',
#  'puf retinu doth deed',
#  'puf wind rain thousand',
#  'puf winnow light away',
#  'puff away thenc turn',
#  'puff barsonpistolpuff puff thi',
#  'puff mine ear present',
#  'puff thi teeth recreant',
#  'puff win vulgar station',
#  'puffd aquilon come stretch',
#  'puffd brother angri someth',
#  'puffd engend black toad',
#  'puffd make mouth invis',
#  'puffd reckless libertin primros',
#  'puffd wind rage like',
#  'puffdrosalinewell like wit gross',
#  'pug tooth edg quart',
#  'pui lair et la',
#  'puisni tilter spur hors',
#  'puissanc either side shall',
#  'puissanc hand god put',
#  'puissanc hold fellow king',
#  'puissanc kinghastingspresent muster grow',
#  'puissanc made littl tastlady',
#  'puissanc need dreadhastingsleav back',
#  'puissanc togeth franc burnd',
#  'puissant arm renew feat',
#  'puissant caesar metellu cimber',
#  'puissant host crave compani',
#  'puissant lieg may morn',
#  'puissant mighti power gallowglass',
#  'puissant navi shore throng',
#  'puissant pikeking henry vevenpistolgood',
#  'puissant power even heard',
#  'puissant seigneurking henry vkiss',
#  'puissant string life began',
#  'puissant troopwarwicksay somervil say',
#  'puke nurs arm whine',
#  'puke stock caddi garter',
#  'pule cuckold would drink',
#  'pule fool whine mammet',
#  'pule lament anger juno',
#  'pule like beggar hallowma',
#  'pull acheron heel marcu',
#  'pull boot harder harderedgaro',
#  'pull countri take thine',
#  'pull ha ha haothellotell',
#  'pull hat upon brow',
#  'pull ladi banishd limb',
#  'pull plume take away',
#  'pull resolut begin doubt',
#  'pull savoy other inn',
#  'pull scarf caesar imag',
#  'pull slow design dull',
#  'pull smack o contrari',
#  'pull thee lesser leg',
#  'pull thi tongu say',
#  'pull yea raiment petticoat',
#  'pullcadehenceforward thing shall commonmessengerlord',
#  'pullcardinal pandulphdenounc curs upon',
#  'pulld fair englandduchessdroop lord',
#  'pulld law uponangeloti one',
#  'pulld o cromwel king',
#  'pulld poor wretch melodi',
#  'puller king henc till',
#  'pullet sperm brewagmistress quicklymarri',
#  'pullpompeyground mistressmistress overdonehere chang',
#  'pullt say rhubarb cyme',
#  'pulpit becom friend speak',
#  'pulpit brutudecius brutuscassiubrutuswhere publiucinnaquit',
#  'pulpit cri liberti freedom',
#  'pulpit first show reason',
#  'pulpit tediou homili love',
#  'pulpit whereto go speech',
#  'puls antipholuof ephesushand let',
#  'puls beat flesh blood',
#  'puls doth temper keep',
#  'puls face twere outfac',
#  'puls fairi motion well',
#  'puls lifesalisburyappar foul play',
#  'puls pale fear hath',
#  'puls power bestow lose',
#  'puls shall keep nativ',
#  'puls twice beatgonzalotorment troubl',
#  'pulsidg beat extraordinarili heart',
#  'pump singl sole worn',
#  'pump unpinkd heel link',
#  'pumpion well teach know',
#  'pun thee shiver fist',
#  'punch full deadli hole',
#  'puni battl slay save',
#  'puni drawer end gave',
#  'puni lie ill tell',
#  'puni subject strike thi',
#  'puni sword frenchmen bloodjoan',
#  'puni whipster get sword',
#  'punish also watch heard',
#  'punish beaten loyalti excit',
#  'punish believ induc potent',
#  'punish believ wring redress',
#  'punish breach king law',
#  'punish cruel death su',
#  'punish cure lunaci ordinari',
#  'punish french caus late',
#  'punish good allegi chosen',
#  'punish hard thought wherein',
#  'punish hate expect love',
#  'punish heard lest shall',
#  'punish heel would amend',
#  'punish height pleasur thou',
#  'punish home weep night',
#  'punish imprison hath three',
#  'punish life taint loveoliviaay',
#  'punish make seem much',
#  'punish man infirmsiciniustwere well',
#  'punish might freer coursalbanygloucest',
#  'punish mistread tell els',
#  'punish murder inde bloodi',
#  'punish must scourg minist',
#  'punish offenc fault suspicion',
#  'punish polici malic even',
#  'punish presum hand opend',
#  'punish remembr penit thou',
#  'punish seem bear lightli',
#  'punish shall desirpagethinkmistress forddevis',
#  'punish show thing found',
#  'punish thank hath got',
#  'punish therefor inde father',
#  'punish thi sweet grace',
#  'punish though outstrip men',
#  'punish treason sufferd harm',
#  'punish trial ye wonder',
#  'punish twa flesh begot',
#  'punish us punish seem',
#  'punish wick lifeallluciu hail',
#  'punish woman forswor prove',
#  'punish women bear made',
#  'punish world weet stand',
#  'punish would punishfirst lordjoy',
#  'punishcostardbound fellow lightli rewardadriano',
#  'punishd bitter fast penitenti',
#  'punishd compens make amend',
#  'punishd duchess uneath may',
#  'punishd ere done mischief',
#  'punishd king must take',
#  'punishd mind forget good',
#  'punishd neer thought offenc',
#  'punishd person child plagu',
#  'punishd sore distract done',
#  'punishd sovereign lest exampl',
#  'punishd thu fright sick',
#  'punishd thwart star warwick',
#  'punishd truth undergo goddess',
#  'punishdcapuleto brother montagu give',
#  'punishdmeneniuswell could say lesscominiusofferd',
#  'punishfirst lordjoy comfort sacr',
#  'punishgreysir show great merci',
#  'punishhermionegaoler kind hostess come',
#  'punishmistress pagelet sent morrow',
#  'punishphilariogentlemen enough came suddenli',
#  'punk lord press death',
#  'punk mani neither maid',
#  'punk tib rush tom',
#  'punto reverso haibenvolionanmercutiopox antic',
#  'punto thi stock thi',
#  'pupil age man enterd',
#  'pupil age present twelv',
#  'pupil becom tutor o',
#  'pupil hath read bring',
#  'pupil lack none nobl',
#  'pupil like take thi',
#  'pupil long hast thou',
#  'pupil mine repast shall',
#  'pupil mineromeobadst buri lovefriar',
#  'pupil present holla within',
#  'pupil still surli gloucest',
#  'pupil thi sentenc speechless',
#  'pupil undertak ben venuto',
#  'puppet aglet babi old',
#  'puppet dalliopheliakeen lord keenhamletwould',
#  'puppet interpretvalentinemadam mistress thousand',
#  'puppet moonshin green sour',
#  'puppet part royalti father',
#  'puppet shalt shown rome',
#  'puppet theetailorsay worship mean',
#  'puppethermiapuppet ay way goe',
#  'puppetpetruchioo monstrou arrog thou',
#  'puppetpetruchiotrue mean make puppet',
#  'puppi dog cannon begot',
#  'puppi doggowercome scot captain',
#  'puppi fifteen litter may',
#  'puppi greyhound hell swagger',
#  'puppi head monster scurvi',
#  'puppi keep door close',
#  'puppi old dam treason',
#  'puppi one save drown',
#  'puppi profess thi friend',
#  'puppiclotenwould come ussecond lord',
#  'puppishepherdwell let us king',
#  'pur cat grayking leararraign',
#  'purblind argu eye sightcressidaman',
#  'purblind eye may findsomersetside',
#  'purblind saycamillobusi lord think',
#  'purblind son heir young',
#  'purchas abus therefor use',
#  'purchas anoth dri bast',
#  'purchas anoth island thou',
#  'purchas bardolph stole lute',
#  'purchas blood enemi valiant',
#  'purchas box o th',
#  'purchas cannot chang choosoctavius',
#  'purchas caparison revenu silli',
#  'purchas corrupt pardon man',
#  'purchas day littl part',
#  'purchas doth inherit pain',
#  'purchas doubl one length',
#  'purchas duteou servic nobl',
#  'purchas easi price yet',
#  'purchas experimothpenni observadriano de',
#  'purchas fall upon thee',
#  'purchas friend give courtezan',
#  'purchas gloriou beauti whenc',
#  'purchas great allianc prove',
#  'purchas heavi curs rome',
#  'purchas honour king exil',
#  'purchas infinit rate hath',
#  'purchas lust eye seduc',
#  'purchas made fruit ensu',
#  'purchas made knownoctavius caesarnay',
#  'purchas make men gloriou',
#  'purchas mani diseas roof',
#  'purchas merit gift thing',
#  'purchas merit wearer mani',
#  'purchas mock biron ill',
#  'purchas money o thou',
#  'purchas remov dwellrosalindtold mani',
#  'purchas semblanc soul state',
#  'purchas sight dear sicilia',
#  'purchas sin pardon henc',
#  'purchas slave like ass',
#  'purchas spice ill sheep',
#  'purchas still last warking',
#  'purchas store think idl',
#  'purchas superflu ratebuckinghambusi reverend',
#  'purchas take daughter thou',
#  'purchas time debt none',
#  'purchas troubl thank give',
#  'purchas true manchamberlainnay rather',
#  'purchas us good opinion',
#  'purchas us thi last',
#  'purchas weight therein work',
#  'purchasethursulasure sure carp commendheroodd',
#  'purchasking edward ivtherein thou',
#  'purchassir andrewsir met theresebastianthere',
#  'purchasvirgiliagod grant truevolumniatrue pow',
#  'pure air fire dull',
#  'pure blood mani lusti',
#  'pure blood mine thou',
#  'pure blush thou mayst',
#  'pure bosom rest king',
#  'pure brain fashiond beatricherohere',
#  'pure brain suppos soul',
#  'pure chastiti sir eglamour',
#  'pure congeal white high',
#  'pure devot calld hundr',
#  'pure elect shine roman',
#  'pure fear entir cowardic',
#  'pure gold forgiv dream',
#  'pure gold verona name',
#  'pure grace infinit man',
#  'pure grief shore old',
#  'pure hand held sad',
#  'pure heart love greet',
#  'pure heart love immacul',
#  'pure heart truth would',
#  'pure hollow bia draw',
#  'pure honour attend foot',
#  'pure honour gain lose',
#  'pure idolatri god amend',
#  'pure immacul valour taken',
#  'pure impieti impiou puriti',
#  'pure innoc owe much',
#  'pure innoc persuad speak',
#  'pure kind hors butter',
#  'pure love cannot call',
#  'pure love danger advers',
#  'pure love dearest skill',
#  'pure love greet mine',
#  'pure love till first',
#  'pure love troubl brain',
#  'pure loveromeoo let us',
#  'pure maiden fall hand',
#  'pure messeng sent heart',
#  'pure mind consider slip',
#  'pure needgloucesterlet whip everi',
#  'pure princ beauti earth',
#  'pure pure idolatri god',
#  'pure respect oblig life',
#  'pure scoffferdinandfarewel mad wench',
#  'pure shame counterfeit rose',
#  'pure sin baptismcanterburyhear graciou',
#  'pure snow poor state',
#  'pure snow thou shalt',
#  'pure soul comeiagozound sir',
#  'pure soul shall princ',
#  'pure soul unto captain',
#  'pure sovereignti sebastianyet would',
#  'pure spirit sens behold',
#  'pure strumpet thi word',
#  'pure surpris fear made',
#  'pure truth corrupt naught',
#  'pure truth labour make',
#  'pure uncleanli apprehens keep',
#  'pure unspot heart never',
#  'pure unsulli lili protest',
#  'pure vestal modesti still',
#  'pure weep doneking claudiuso',
#  'pure white robe like',
#  'pure white seal blisshelenao',
#  'pure wit thou partest',
#  'pureapemantusleprosi thou speaksttimonname thee',
#  'purer airlysimachusthink thou couldst',
#  'purer blanch love ambiti',
#  'purer half good night',
#  'purest bed thou valiant',
#  'purest snow hang dian',
#  'purest spring free mud',
#  'purest treasur mortal time',
#  'purest wive foul slanderothellobid',
#  'puretalbotmaid saybedfordmaid martialburgundypray god',
#  'purg air pestil instant',
#  'purg arrest high name',
#  'purg away forbid tell',
#  'purg black despairwarwicksee pang',
#  'purg blood newli joind',
#  'purg choler without let',
#  'purg condemn excusprincesay thou',
#  'purg deposbastardheaven scroyl angier',
#  'purg desper chang particular',
#  'purg drop uslennoxmuch need',
#  'purg drug would scour',
#  'purg field hild foe',
#  'purg fire sparkl lover',
#  'purg gentl weal ay',
#  'purg grudg hate hand',
#  'purg humour press sleepleontesnois',
#  'purg infect air whilst',
#  'purg judgment trust neither',
#  'purg land drone rob',
#  'purg leav sack live',
#  'purg mani charg withal',
#  'purg melancholi air thou',
#  'purg obstruct begin stop',
#  'purg scum ruffian swear',
#  'purg sent word dead',
#  'purg soul fit seasond',
#  'purg sound pristin health',
#  ...]

# %%
act_ngram.shape
# Out:
# (187, 5000)
