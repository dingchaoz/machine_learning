# %%
## Trying different feature extraction methods from sckitlearn and see if can be applied to HW4
## More note can be found in the trial and test note.docx

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

import pandas as pd
import numpy as np


# Initialize the "TfidVectorizer" object, which is scikit-learn's
# bag of words tool. http://scikit-learn.org/dev/modules/feature_extraction.html#text-feature-extraction
vectorizer = TfidfVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000)


## Initialize n-gram vectorizer
ngram2_vectorizer = CountVectorizer(ngram_range=(2, 2),token_pattern=r'\b\w+\b', min_df=1, max_features = 5000)
ngram4_vectorizer = CountVectorizer(ngram_range=(4, 4),token_pattern=r'\b\w+\b', min_df=1, max_features = 5000)


## These following two tools are also initialized, but can't be used report dtype error
## TO-DO: need to fix it
transformer = TfidfTransformer()
hashvect = HashingVectorizer()

#import file
df = pd.read_csv('Data/all_poems_tokenized.txt',sep='\t')

# Get all the poem names
poemnames = pd.unique(df.poem_name.ravel())

# Array to hold bag of words for each poem
poem_bagwords = []
# Arrays to hold labels
poem_label = []

# Vectorizer results are normalized, which makes KMeans behave as
# spherical k-means for better results. Since LSA/SVD results are
# not normalized, we have to redo the normalization.
# svd = TruncatedSVD()
# normalizer = Normalizer(copy=False)
# lsa = make_pipeline(svd, normalizer)

## loop through all poems
for i in range(len(poemnames)):
    
    ### Create bag of words for all plays
    p = df[df['poem_name'] == poemnames[i]] # Get the sub data frame of each play
    s = "" # Initiate empty string to hold bag of words for play
    # Iterate all the rows to append the poem words to a string
    for index,row in p.iterrows():
        s += str(row['poem'])

    # Append the bag of words to each poem
    poem_bagwords.append(s)
    # Append the label to each row
    poem_label.append(str(poemnames[i]))
    
f = open("poem_feature_labels.txt", "w")
f.write("\n".join(map(lambda x: str(x), poem_label)))
f.close()



# Vectorize analyze the similarities among poems
# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
poem_vect = vectorizer.fit_transform(poem_bagwords)
poem_ngram2= ngram2_vectorizer.fit_transform(poem_bagwords)
poem_ngram2 = poem_ngram2.toarray() 
poem_ngram4 = ngram4_vectorizer.fit_transform(poem_bagwords)
poem_ngram4 = poem_ngram4.toarray() 


# # Numpy arrays are easy to work with, so convert the result to an 
# # array
poem_feature = poem_vect.toarray() # Show the similarity array of plays
# poem_feature2 = lsa.fit_transform(play_feature) # Apply Latent Semantic Analysis
# explained_variance = svd.explained_variance_ratio_.sum()
# print(explained_variance)


# See the data arrary: print (play_feature.shape)

# Write the plays feature array to a csv file
np.savetxt("Poem_Features_Vectorize.txt", poem_feature, delimiter=",")
np.savetxt("Poem_Features_ngram2.txt", poem_ngram2, delimiter=",")
np.savetxt("Poem_Features_ngram4.txt", poem_ngram4, delimiter=",")
# np.savetxt("Poem_Features_Vectorize_LSA.txt", poem_feature2, delimiter=",")

# Take a look at the words in the vocabulary
# vocab = vectorizer.get_feature_names()

# import numpy as np
# print(vocab)

### Print the count of each word in vocab -- not working somehow
# # Sum up the counts of each vocabulary word
# dist = np.sum(play_feature, axis=0)
# # For each, print the vocabulary word and the number of times it 
# # appears in the training set
# for tag, count in zip(vocab, dist):
#     print (count, tag)



#Y = transformer.fit_transform(play_bagwords) -- To DO fix the error: no supported conversion for types: (dtype('<U98727')

# %%
ngram2_vectorizer.get_feature_names()
# Out:
# ['1612 normal',
#  'absent thi',
#  'act thi',
#  'adoni live',
#  'age yet',
#  'aid vers',
#  'air let',
#  'alon thou',
#  'angri eye',
#  'antiqu pen',
#  'appear like',
#  'appli love',
#  'arm bound',
#  'art beauti',
#  'art dead',
#  'art made',
#  'art man',
#  'art therefor',
#  'art thi',
#  'art thou',
#  'ashi pale',
#  'attend time',
#  'author thi',
#  'away face',
#  'bare everi',
#  'bark peeld',
#  'bear dead',
#  'bear thee',
#  'bear thi',
#  'beast bear',
#  'beast know',
#  'beauti dead',
#  'beauti doth',
#  'beauti hath',
#  'beauti hold',
#  'beauti lie',
#  'beauti live',
#  'beauti may',
#  'beauti red',
#  'beauti set',
#  'beauti shall',
#  'beauti still',
#  'beauti success',
#  'beauti thi',
#  'beauti thou',
#  'beauti use',
#  'behold face',
#  'behold thi',
#  'believ love',
#  'believ though',
#  'belong thi',
#  'besieg ardea',
#  'best best',
#  'best love',
#  'better angel',
#  'better life',
#  'better part',
#  'black face',
#  'black night',
#  'blood staind',
#  'blood wateri',
#  'blush shame',
#  'boar whose',
#  'brain full',
#  'break day',
#  'breast doth',
#  'breast sun',
#  'breath breath',
#  'breath forth',
#  'breath live',
#  'bright day',
#  'bright eye',
#  'bring forth',
#  'burn eye',
#  'burn long',
#  'burn thi',
#  'burn troy',
#  'bush fear',
#  'busi care',
#  'call thee',
#  'canker eat',
#  'cannot choos',
#  'canst thou',
#  'chang state',
#  'chang thi',
#  'chide thi',
#  'closur breast',
#  'cloud eclips',
#  'coal black',
#  'come back',
#  'come shall',
#  'comment upon',
#  'could see',
#  'cri till',
#  'crime o',
#  'cun love',
#  'dare bold',
#  'dark night',
#  'date cancelld',
#  'day day',
#  'day doth',
#  'day eye',
#  'day make',
#  'day night',
#  'day say',
#  'day seem',
#  'day thou',
#  'dead night',
#  'dead still',
#  'dear friend',
#  'dear heart',
#  'dear love',
#  'death cannot',
#  'death death',
#  'death live',
#  'death may',
#  'death thou',
#  'deep groan',
#  'deep regard',
#  'desir doth',
#  'desir hath',
#  'despit thi',
#  'destroy love',
#  'didst thou',
#  'die coal',
#  'die flower',
#  'die life',
#  'die till',
#  'dim mist',
#  'dishevelld hair',
#  'dost lie',
#  'dost thou',
#  'doth bear',
#  'doth beauti',
#  'doth begin',
#  'doth behold',
#  'doth call',
#  'doth cover',
#  'doth dwell',
#  'doth fight',
#  'doth flatter',
#  'doth give',
#  'doth grow',
#  'doth lend',
#  'doth lie',
#  'doth live',
#  'doth love',
#  'doth make',
#  'doth stand',
#  'doth stay',
#  'doth tarquin',
#  'doth teach',
#  'doth tell',
#  'doth thi',
#  'doth use',
#  'doth view',
#  'doth yield',
#  'drown eye',
#  'duti william',
#  'ear heavi',
#  'ear thi',
#  'earl southampton',
#  'embrac like',
#  'end doth',
#  'end thi',
#  'ere long',
#  'ere thou',
#  'even doth',
#  'ever love',
#  'ever yet',
#  'everi eye',
#  'everi fair',
#  'everi hour',
#  'everi light',
#  'everi one',
#  'everi part',
#  'everi thing',
#  'everi tongu',
#  'everi vulgar',
#  'exampl thou',
#  'excus thi',
#  'eye alon',
#  'eye behold',
#  'eye could',
#  'eye doth',
#  'eye ear',
#  'eye even',
#  'eye eye',
#  'eye hath',
#  'eye heart',
#  'eye heaven',
#  'eye like',
#  'eye look',
#  'eye love',
#  'eye make',
#  'eye may',
#  'eye men',
#  'eye mind',
#  'eye opend',
#  'eye saw',
#  'eye scorn',
#  'eye see',
#  'eye seen',
#  'eye taught',
#  'eye thee',
#  'eye thi',
#  'eye thou',
#  'eye true',
#  'eye well',
#  'face sweet',
#  'faint heart',
#  'fair cheek',
#  'fair eye',
#  'fair fair',
#  'fair flower',
#  'fair hand',
#  'fair kind',
#  'fair lord',
#  'fair sun',
#  'fall thi',
#  'fals desir',
#  'fals heart',
#  'far home',
#  'fast thou',
#  'fault cleanli',
#  'fault find',
#  'fault thi',
#  'fear doth',
#  'feebl age',
#  'find face',
#  'find lucrec',
#  'find thi',
#  'find true',
#  'fire burneth',
#  'fire doth',
#  'fire shall',
#  'fit trespass',
#  'flatter thee',
#  'flight make',
#  'flower gatherd',
#  'flower sweet',
#  'fool love',
#  'forc must',
#  'form receiv',
#  'forth fire',
#  'foul act',
#  'foul face',
#  'frame thee',
#  'fresh beauti',
#  'friend friend',
#  'friend hath',
#  'friend sake',
#  'full care',
#  'full fear',
#  'gainst law',
#  'gaze upon',
#  'gentl love',
#  'give due',
#  'give life',
#  'give oer',
#  'give physic',
#  'give sorrow',
#  'give thee',
#  'give thi',
#  'give thyself',
#  'glass show',
#  'glow fire',
#  'good morrow',
#  'good night',
#  'good report',
#  'good thought',
#  'good turn',
#  'gore whose',
#  'grant thou',
#  'grief may',
#  'grief sustain',
#  'ground sin',
#  'grow thi',
#  'guest whose',
#  'guilt great',
#  'hadst love',
#  'hammerd steel',
#  'hand defac',
#  'hand foot',
#  'hand hand',
#  'hang head',
#  'hard heart',
#  'harder stone',
#  'harm done',
#  'hast thou',
#  'hate foe',
#  'hate hate',
#  'hate love',
#  'hath done',
#  'hath end',
#  'hath eye',
#  'hath fed',
#  'hath killd',
#  'hath made',
#  'hath nought',
#  'hath power',
#  'hath put',
#  'hath said',
#  'hath taught',
#  'hath thee',
#  'hath wrought',
#  'hear see',
#  'hear thi',
#  'heart anoth',
#  'heart bleed',
#  'heart command',
#  'heart eye',
#  'heart hath',
#  'heart lead',
#  'heart love',
#  'heart mine',
#  'heart shall',
#  'heart thi',
#  'heart thine',
#  'heart wound',
#  'heav hand',
#  'heaven air',
#  'heaven shine',
#  'heavenli moistur',
#  'heavi sleep',
#  'henri wriothesli',
#  'high low',
#  'high wind',
#  'hold disput',
#  'hold thee',
#  'honor henri',
#  'honour thi',
#  'honour wealth',
#  'hot burn',
#  'hot desir',
#  'hour love',
#  'hour mine',
#  'hue white',
#  'hunt boar',
#  'husband love',
#  'idl hour',
#  'ill bequeath',
#  'ill well',
#  'immort life',
#  'incertainti crown',
#  'issu sweet',
#  'joint shake',
#  'keep still',
#  'keep thi',
#  'kill kill',
#  'kill thi',
#  'kind true',
#  'kindl fire',
#  'kiss good',
#  'kiss shall',
#  'kiss speak',
#  'know conscienc',
#  'know gentl',
#  'know heart',
#  'know thi',
#  'law reason',
#  'learn read',
#  'leav love',
#  'leav thi',
#  'leav thing',
#  'left behind',
#  'lend light',
#  'lend thee',
#  'lend word',
#  'let copi',
#  'let fair',
#  'let go',
#  'let love',
#  'let time',
#  'let us',
#  'lie o',
#  'life death',
#  'life decay',
#  'life foul',
#  'life hath',
#  'life honour',
#  'life live',
#  'life one',
#  'life thi',
#  'life thou',
#  'light make',
#  'light thou',
#  'like ivori',
#  'like man',
#  'like old',
#  'like one',
#  'like sluic',
#  'like still',
#  'like two',
#  'like virtuou',
#  'lili white',
#  'lip kiss',
#  'lip sinc',
#  'lip sweet',
#  'lip thine',
#  'listen ear',
#  'littl harm',
#  'littl star',
#  'live death',
#  'live die',
#  'live life',
#  'live sweet',
#  'live thine',
#  'live thou',
#  'lo thu',
#  'long hear',
#  'long live',
#  'long sinc',
#  'look best',
#  'look eye',
#  'look mine',
#  'look thee',
#  'look thi',
#  'look upon',
#  'lord love',
#  'lord rome',
#  'loss love',
#  'love alon',
#  'love alter',
#  'love beauti',
#  'love best',
#  'love call',
#  'love calld',
#  'love desir',
#  'love disgrac',
#  'love dost',
#  'love doth',
#  'love eye',
#  'love fair',
#  'love fire',
#  'love gentl',
#  'love hate',
#  'love hath',
#  'love keep',
#  'love know',
#  'love less',
#  'love look',
#  'love love',
#  'love made',
#  'love may',
#  'love one',
#  'love piti',
#  'love put',
#  'love shall',
#  'love still',
#  'love stop',
#  'love swear',
#  'love sweet',
#  'love thee',
#  'love thi',
#  'love thine',
#  'love thou',
#  'love though',
#  'love thought',
#  'love thu',
#  'love thyself',
#  'love time',
#  'love touch',
#  'love upon',
#  'love well',
#  'love whose',
#  'love yet',
#  'love youth',
#  'lucrec side',
#  'lucretiu give',
#  'mad mad',
#  'made thee',
#  'make bright',
#  'make defenc',
#  'make love',
#  'make mine',
#  'make moan',
#  'make red',
#  'make seem',
#  'make stay',
#  'make still',
#  'make summer',
#  'make thee',
#  'make thi',
#  'make thou',
#  'make true',
#  'make war',
#  'make weak',
#  'make wound',
#  'make young',
#  'mani live',
#  'marvel though',
#  'matur wherewith',
#  'maund drew',
#  'maw even',
#  'may affair',
#  'may alway',
#  'may april',
#  'may aris',
#  'may aught',
#  'may bath',
#  'may behold',
#  'may better',
#  'may blest',
#  'may bold',
#  'may calld',
#  'may chang',
#  'may charact',
#  'may compar',
#  'may convey',
#  'may dare',
#  'may deceiv',
#  'may depart',
#  'may deserv',
#  'may detain',
#  'may directli',
#  'may evermor',
#  'may express',
#  'may feel',
#  'may find',
#  'may forc',
#  'may get',
#  'may give',
#  'may grace',
#  'may heavi',
#  'may hide',
#  'may imagin',
#  'may keep',
#  'may kiss',
#  'may know',
#  'may lend',
#  'may likewis',
#  'may live',
#  'may make',
#  'may neither',
#  'may obtaind',
#  'may possess',
#  'may privileg',
#  'may prove',
#  'may pure',
#  'may read',
#  'may remov',
#  'may said',
#  'may say',
#  'may see',
#  'may seem',
#  'may set',
#  'may sing',
#  'may spi',
#  'may stain',
#  'may still',
#  'may stop',
#  'may straight',
#  'may suffer',
#  'may summer',
#  'may surpris',
#  'may tear',
#  'may term',
#  'may thou',
#  'may time',
#  'may triumph',
#  'may view',
#  'may vow',
#  'mayest tarquin',
#  'mayst behold',
#  'mayst call',
#  'mayst come',
#  'mayst fals',
#  'mayst know',
#  'mayst prove',
#  'mayst take',
#  'mayst thi',
#  'mayst thou',
#  'mayst true',
#  'mayst without',
#  'maze cannot',
#  'mead sun',
#  'meado let',
#  'meadow green',
#  'meagr lean',
#  'mean bear',
#  'mean bless',
#  'mean burn',
#  'mean chide',
#  'mean end',
#  'mean fret',
#  'mean immur',
#  'mean mourn',
#  'mean parl',
#  'mean place',
#  'mean public',
#  'mean stifl',
#  'mean struck',
#  'mean world',
#  'meaner men',
#  'meant therebi',
#  'meantender spring',
#  'meantim bound',
#  'measur better',
#  'measur stare',
#  'measur strang',
#  'measur thi',
#  'mediat forc',
#  'medicin health',
#  'medit alack',
#  'meed propos',
#  'meed thousand',
#  'meek like',
#  'meet anoth',
#  'meet basest',
#  'meet cloud',
#  'meet diseas',
#  'meet eastern',
#  'meet greater',
#  'meet lees',
#  'meet morrow',
#  'meet one',
#  'meet opportunpatient',
#  'melancholi life',
#  'melancholi malcont',
#  'mellow plum',
#  'melodi discord',
#  'melodi mirth',
#  'melt buttock',
#  'melt dew',
#  'melt eye',
#  'melt like',
#  'melt midday',
#  'melt mine',
#  'melt scorn',
#  'melt snowmistress',
#  'melt tear',
#  'melt though',
#  'meltbid discours',
#  'memori conceit',
#  'memori contain',
#  'memori death',
#  'memori gainst',
#  'memori hath',
#  'memori shall',
#  'memori still',
#  'memori sweet',
#  'memori thou',
#  'men abus',
#  'men armi',
#  'men bad',
#  'men bid',
#  'men breath',
#  'men cover',
#  'men death',
#  'men diseas',
#  'men dote',
#  'men eye',
#  'men fault',
#  'men give',
#  'men hell',
#  'men kiss',
#  'men less',
#  'men loop',
#  'men make',
#  'men mind',
#  'men move',
#  'men nativ',
#  'men o',
#  'men plant',
#  'men pride',
#  'men prove',
#  'men ride',
#  'men rough',
#  'men thiev',
#  'men thrall',
#  'men vaunt',
#  'men without',
#  'men would',
#  'men yet',
#  'mend hurt',
#  'mend mar',
#  'mend style',
#  'mend tongu',
#  'mend whether',
#  'merchand whose',
#  'merchant fear',
#  'merchant loss',
#  'merci come',
#  'merci mortal',
#  'merci sever',
#  'merciless conclus',
#  'merciless pitchi',
#  'mere art',
#  'mere garment',
#  'merit eye',
#  'merit hath',
#  'merit live',
#  'merit noth',
#  'merit reprov',
#  'merit respect',
#  'meritori fair',
#  'mermaid ear',
#  'mermaid song',
#  'mermaid voic',
#  'merri compani',
#  'merri fool',
#  'merri guest',
#  'merri horn',
#  'messeng come',
#  'messeng one',
#  'messeng returnd',
#  'met boar',
#  'met far',
#  'metal amor',
#  'methink astronomi',
#  'methink dead',
#  'methink face',
#  'methink still',
#  'method compound',
#  'metr antiqu',
#  'mettl rider',
#  'mid day',
#  'midday suntherefor',
#  'middl age',
#  'midnight shine',
#  'midst sentenc',
#  'might bear',
#  'might becom',
#  'might behold',
#  'might better',
#  'might black',
#  'might buri',
#  'might charm',
#  'might compass',
#  'might dart',
#  'might depart',
#  'might done',
#  'might ensu',
#  'might espous',
#  'might ever',
#  'might excus',
#  'might fortun',
#  'might insuffici',
#  'might love',
#  'might make',
#  'might master',
#  'might never',
#  'might noth',
#  'might o',
#  'might oer',
#  'might one',
#  'might open',
#  'might plead',
#  'might rememberd',
#  'might repos',
#  'might reproof',
#  'might say',
#  'might see',
#  'might show',
#  'might speak',
#  'might spendst',
#  'might stem',
#  'might strain',
#  'might teach',
#  'might think',
#  'might unus',
#  'might uphold',
#  'might yet',
#  'mightest seat',
#  'mighti rome',
#  'mighti thine',
#  'mightier man',
#  'mightier thing',
#  'mightier way',
#  'mightili note',
#  'mighto pardon',
#  'mightst thou',
#  'mihi flavu',
#  'milch doe',
#  'mild continu',
#  'mild glanc',
#  'mild grief',
#  'mild imag',
#  'mild make',
#  'mild patienc',
#  'mild wilder',
#  'mild women',
#  'mile measur',
#  'mile thou',
#  'milk blood',
#  'million strang',
#  'milliond accid',
#  'mind admit',
#  'mind bodi',
#  'mind brought',
#  'mind confound',
#  'mind cours',
#  'mind crownd',
#  'mind doth',
#  'mind first',
#  'mind forc',
#  'mind foul',
#  'mind frantic',
#  'mind given',
#  'mind govern',
#  'mind grief',
#  'mind guess',
#  'mind hand',
#  'mind hang',
#  'mind ill',
#  'mind imprint',
#  'mind kingli',
#  'mind like',
#  'mind look',
#  'mind love',
#  'mind offic',
#  'mind part',
#  'mind proce',
#  'mind proud',
#  'mind see',
#  'mind shall',
#  'mind sight',
#  'mind sinc',
#  'mind take',
#  'mind thee',
#  'mind therefor',
#  'mind thi',
#  'mind thought',
#  'mind thu',
#  'mind time',
#  'mind tongu',
#  'mind untaint',
#  'mind visag',
#  'mind wail',
#  'mind wakeone',
#  'mindeven subtl',
#  'mindlike thievish',
#  'mindone man',
#  'mindpoor fright',
#  'mine appetit',
#  'mine care',
#  'mine compar',
#  'mine depend',
#  'mine desert',
#  'mine ear',
#  'mine enemi',
#  'mine ere',
#  'mine excus',
#  'mine eye',
#  'mine fair',
#  'mine fear',
#  'mine free',
#  'mine hardshame',
#  'mine hath',
#  'mine honour',
#  'mine ill',
#  'mine importun',
#  'mine infami',
#  'mine infamisaid',
#  'mine lend',
#  'mine life',
#  'mine love',
#  'mine make',
#  'mine mask',
#  'mine may',
#  'mine mine',
#  'mine must',
#  'mine o',
#  'mine offenc',
#  'mine pour',
#  'mine prais',
#  'mine ransom',
#  'mine region',
#  'mine repli',
#  'mine restorplenitud',
#  'mine reveng',
#  'mine robbd',
#  'mine seest',
#  'mine self',
#  'mine shall',
#  'mine shape',
#  'mine slain',
#  'mine suppos',
#  'mine thi',
#  'mine thine',
#  'mine thou',
#  'mine thought',
#  'mine ti',
#  'mine true',
#  'mine weak',
#  'mine worth',
#  'mine would',
#  'minedone quoth',
#  'minethu forestal',
#  'mingl beauti',
#  'mingl blush',
#  'mingl hot',
#  'mingl talk',
#  'mingl togeth',
#  'minion pleasur',
#  'minist obey',
#  'ministret aquaright',
#  'minor right',
#  'minstrel tune',
#  'minut age',
#  'minut fight',
#  'minut fill',
#  'minut hasten',
#  'minut hour',
#  'minut kill',
#  'minut mirth',
#  'minut pay',
#  'minut tell',
#  'minut wast',
#  'miracl labor',
#  'miracl might',
#  'mire unperceiv',
#  'miretur vulgu',
#  'mirror dim',
#  'mirth doth',
#  'mirth wail',
#  'miscalld simplic',
#  'mischanc cross',
#  'mischanc make',
#  'mischanc much',
#  'mischief thi',
#  'mischief wors',
#  'misde askanc',
#  'misde cannot',
#  'miser wealth',
#  'miseri burn',
#  'miseri trodden',
#  'misfortun carv',
#  'misgovern seek',
#  'mishap poor',
#  'misl give',
#  'misplac maiden',
#  'mispris grow',
#  'miss follow',
#  'miss seek',
#  'missd littl',
#  'missd poor',
#  'mist aspir',
#  'mist meet',
#  'mist thi',
#  'mistak aim',
#  'mistak brain',
#  'mistak smell',
#  'mistak thi',
#  'mistak view',
#  'misti night',
#  'misti vapour',
#  'mistook matter',
#  'mistress brow',
#  'mistress eye',
#  'mistress fate',
#  'mistress heart',
#  'mistress hie',
#  'mistress mount',
#  'mistress ornament',
#  'mistress passion',
#  'mistress reek',
#  'mistress sky',
#  'mistress thrall',
#  'mistress walk',
#  'mistress wrack',
#  'mistrust fals',
#  'mistrust servitor',
#  'mistrust shall',
#  'mistrust two',
#  'mistrust wood',
#  'misus thee',
#  'mixd cloud',
#  'mixd oratori',
#  'mixd second',
#  'moan expens',
#  'moan mad',
#  'moan merit',
#  'moan mock',
#  'moan move',
#  'moan new',
#  'moan passion',
#  'moan piti',
#  'moan plaint',
#  'moan receiv',
#  'moan stone',
#  'moan tire',
#  'moanlo trophi',
#  'moano night',
#  'mock gone',
#  'mock mindone',
#  'mock presag',
#  'mock resort',
#  'mock sight',
#  'mock subtl',
#  'mock thi',
#  'modern quill',
#  'modest dian',
#  'modest eloqu',
#  'modest eye',
#  'modest lucrec',
#  'modest pride',
#  'modest snow',
#  'modest wanton',
#  ...]

# %%
ngram4_vectorizer.get_feature_names()
# Out:
# ['1612 normal text ed',
#  'henri wriothesli earl southampton',
#  'honor henri wriothesli earl',
#  'love thee sort thou',
#  'mani nymph vowd chast',
#  'mani one perus sighd',
#  'mani ring posi gold',
#  'mani see care carv',
#  'mani seem one sing',
#  'mani sever fair kind',
#  'mani thine alon imag',
#  'mani thing sought old',
#  'mani thou none lovest',
#  'mani trojan mother share',
#  'mani vanishd sight griev',
#  'manifold sever stone wit',
#  'manli chivalri bruis arm',
#  'manli hector faint troilu',
#  'manli shame bid possess',
#  'manner breed thenc come',
#  'manner deal nwithal suddenli',
#  'manner expressli told ajax',
#  'manner hold still comment',
#  'manner may sing thou',
#  'manner piti want pain',
#  'manner vile deed nbitter',
#  'mansion batterd enemi sacr',
#  'mansion spend shall worm',
#  'mansion thought assignd labour',
#  'mansion vice got habit',
#  'mantl rude oer arm',
#  'manual wax red lipthousand',
#  'map day outworn beauti',
#  'map death death dim',
#  'map deep impress bear',
#  'map doth natur store',
#  'mar subject well pass',
#  'mar sword war quick',
#  'mar thing cannot amend',
#  'marbl gild monument princ',
#  'marbl weak oppressd impress',
#  'marbl wear rainpiti plead',
#  'marbl women waxen mind',
#  'march rank better equipag',
#  'march thick smoki rank',
#  'march trembl pace heartless',
#  'marchd field stood mani',
#  'marchd make stand bare',
#  'marcheth lucrec bedlock chamber',
#  'marethu repli thi palfrey',
#  'margent book touchd unknown',
#  'margent set like usuri',
#  'marigold sheath light canopi',
#  'marigold sun eye pride',
#  'marjoram stoln thi hair',
#  'mark descri men nativ',
#  'mark ever yet fair',
#  'mark everi open eye',
#  'mark face white sawst',
#  'mark feebl age thi',
#  'mark look tempest never',
#  'mark modesti sort sad',
#  'mark neglect dispens strongli',
#  'mark one string sweet',
#  'mark poor wretch overshoot',
#  'mark slow time goe',
#  'mark tell trembl fear',
#  'mark thee earth delight',
#  'marketh even wind hushd',
#  'marrd kiss good never',
#  'marri muse therefor mayst',
#  'marri offend thine ear',
#  'marriag blur youth sorrow',
#  'marriag true mind admit',
#  'marrow burn smooth moist',
#  'marrow eat sick whose',
#  'martial man soft fanci',
#  'martyrd disgrac keep still',
#  'marvel though mistak view',
#  'marvel though thi hors',
#  'mask brow hide infami',
#  'mask bud disclos virtu',
#  'maskd thi show thou',
#  'maskd yet love whit',
#  'masonri mar sword war',
#  'master anoth lick wound',
#  'master foild god fighttouch',
#  'master goeth take lo',
#  'master mistress passion woman',
#  'master prais propheci time',
#  'master shall meet morrow',
#  'master strive play place',
#  'master william peter nlondon',
#  'masterd leathern rein saw',
#  'masterd young pride present',
#  'match tell morrow intend',
#  'match woeshall fickl fals',
#  'matcheth thi show solv',
#  'mate delay like proceed',
#  'mate reckon fortun high',
#  'matter although foot stand',
#  'matter appli cautel strang',
#  'matter fire sith prime',
#  'matter quoth leav stori',
#  'matter slay slain foecourag',
#  'matur wherewith crownd crook',
#  'maund drew amber crystal',
#  'maw even languisheth mishap',
#  'may affair suppos like',
#  'may alway answer wish',
#  'may april see wind',
#  'may aris look scorn',
#  'may aught appli may',
#  'may bath coal black',
#  'may behold day day',
#  'may better thrive death',
#  'may blest lover say',
#  'may bold would request',
#  'may calld hell felt',
#  'may chang mind shall',
#  'may charact hath figur',
#  'may compar well one',
#  'may convey troubl soulyet',
#  'may dare boast love',
#  'may deceiv fear hear',
#  'may depart resolv longer',
#  'may deserv piti thou',
#  'may detain still keep',
#  'may directli tell friend',
#  'may evermor acknowledg thee',
#  'may express love thi',
#  'may feel heart poor',
#  'may find purer chest',
#  'may forc stain wipequaliti',
#  'may get whoever plot',
#  'may give due thee',
#  'may give redressthree time',
#  'may grace fashion disgrac',
#  'may heavi groan advantag',
#  'may hide listcrow may',
#  'may imagin foul enforc',
#  'may keep children eye',
#  'may kiss cure o',
#  'may know grief grief',
#  'may lend thee light',
#  'may likewis sepulchr thi',
#  'may live thine thee',
#  'may live thou thyself',
#  'may make seem bare',
#  'may make still seal',
#  'may neither parti true',
#  'may obtaind wilt thou',
#  'may possess claim lay',
#  'may privileg time doth',
#  'may prove plead hath',
#  'may pure mind foul',
#  'may read mot afar',
#  'may said free vent',
#  'may said love dearli',
#  'may say learnd sin',
#  'may say plagu banishd',
#  'may see pleasur sometim',
#  'may seem fals love',
#  'may set noon make',
#  'may sing thou art',
#  'may spi sit sin',
#  'may stain heaven sun',
#  'may still seem love',
#  'may still shine bright',
#  'may stop awhil stay',
#  'may straight though bevel',
#  'may suffer ecstasi assuag',
#  'may summer leas hath',
#  'may surpris silli lamb',
#  'may tear thi heat',
#  'may term acquit chanc',
#  'may thou beli bear',
#  'may thou hast eye',
#  'may thou shouldst think',
#  'may time disgrac wretch',
#  'may triumph love flesh',
#  'may view els call',
#  'may vow sad hour',
#  'mayest tarquin must use',
#  'mayst behold yellow leav',
#  'mayst call thine thou',
#  'mayst come part even',
#  'mayst fals yet know',
#  'mayst know time thievish',
#  'mayst take away wretch',
#  'mayst thi thou turn',
#  'mayst thou tast wrinkl',
#  'mayst thou well tast',
#  'mayst true love call',
#  'mayst without attaint oerlook',
#  'maze cannot tread way',
#  'mead sun doth melt',
#  'meado let keep loathsom',
#  'meadow green gild pale',
#  'meagr lean hate divorc',
#  'mean bear thee unto',
#  'mean bless barren rhyme',
#  'mean burn troy waterenrag',
#  'mean chide thi beauti',
#  'mean end hapless life',
#  'mean fret upon instrument',
#  'mean immur seenknow shall',
#  'mean mourn newer waylast',
#  'mean parl look read',
#  'mean place swear slew',
#  'mean public manner breed',
#  'mean stifl beauti steal',
#  'mean struck ere word',
#  'mean world say love',
#  'meaner men vaunt golden',
#  'meant therebi thou shouldst',
#  'meantender spring upon thi',
#  'meantim bound lordship nto',
#  'measur better one gener',
#  'measur stare ruffian shall',
#  'measur strang unrip year',
#  'measur thi deed churl',
#  'measur thi friend beast',
#  'mediat forc argument straw',
#  'medicin health state rank',
#  'medit alack shall time',
#  'meed propos though death',
#  'meed thousand honey secret',
#  'meek like bankrupt beggar',
#  'meet anoth sadli scowl',
#  'meet basest weed outbrav',
#  'meet cloud contend merciless',
#  'meet diseas ere true',
#  'meet eastern light make',
#  'meet greater rank join',
#  'meet lees show substanc',
#  'meet morrow say shall',
#  'meet one even tent',
#  'meet opportunpatient die physician',
#  'melancholi life composit recur',
#  'melancholi malcont veil tail',
#  'mellow plum doth fall',
#  'melodi discord heavenli tune',
#  'melodi mirth doth search',
#  'melt buttock lent stamp',
#  'melt dew golden splendor',
#  'melt eye even maid',
#  'melt like vapour sight',
#  'melt midday suntherefor despit',
#  'melt mine eye red',
#  'melt scorn pass wash',
#  'melt snowmistress doth give',
#  'melt tear compassion soft',
#  'melt though drop differ',
#  'meltbid discours enchant thine',
#  'memori conceit inconst stay',
#  'memori contain commit wast',
#  'memori death cannot take',
#  'memori gainst death oblivi',
#  'memori hath crave nfrom',
#  'memori shall idl rank',
#  'memori still thee shall',
#  'memori sweet love beauti',
#  'memori thou contract thine',
#  'memori thou thi dial',
#  'men abus proud lord',
#  'men armi meet one',
#  'men bad bad reign',
#  'men bid thou readi',
#  'men breath eye see',
#  'men cover crime bold',
#  'men death dead there',
#  'men death near news',
#  'men diseas mistress thrall',
#  'men dote love wise',
#  'men eye alon beweep',
#  'men eye shall lie',
#  'men eye women soul',
#  'men fault seldom appear',
#  'men give away keep',
#  'men kiss even directsaid',
#  'men less truth tongu',
#  'men loop hole thrust',
#  'men make fault even',
#  'men mind confound mutini',
#  'men move storm oft',
#  'men nativ natur fault',
#  'men o love eye',
#  'men o vouchsaf love',
#  'men plant increas cheer',
#  'men pride boast wretch',
#  'men prove beast let',
#  'men prove strang maladi',
#  'men ride eye falsehood',
#  'men rough grown grove',
#  'men thiev thi lip',
#  'men thrall old men',
#  'men vaunt golden hap',
#  'men without orat needeth',
#  'men would say hors',
#  'men yet thi worst',
#  'mend hurt unkind marrd',
#  'mend mar subject well',
#  'mend style art thi',
#  'mend tongu voic soul',
#  'mend whether better whether',
#  'merchand whose rich esteem',
#  'merchant fear ere rich',
#  'merchant loss head declin',
#  'merci come chide tongu',
#  'merci mortal stingchamber wickedli',
#  'merci sever deceiv seem',
#  'merciless conclus two sweet',
#  'merciless pitchi night fold',
#  'mere art bastard foul',
#  'mere garment grace nake',
#  'merit eye scorn upon',
#  'merit hath duti strongli',
#  'merit live love death',
#  'merit noth sweet boy',
#  'merit reprov lip thine',
#  'merit respect proud thi',
#  'meritori fair design chase',
#  'mermaid ear entic high',
#  'mermaid song yet mine',
#  'mermaid voic hath done',
#  'merri compani grief best',
#  'merri fool mock resort',
#  'merri guest relish nimbl',
#  'merri horn whereat leap',
#  'messeng come back bring',
#  'messeng one rome father',
#  'messeng returnd thee even',
#  'met boar bloodi beast',
#  'met far home wonder',
#  'metal amor impleachd receiv',
#  'methink astronomi tell good',
#  'methink face graciou mine',
#  'methink still doth stand',
#  'method compound strang write',
#  'metr antiqu song child',
#  'mettl rider take proud',
#  'mid day heat burn',
#  'midday suntherefor despit fruitless',
#  'middl age yet mortal',
#  'midnight shine falchion chamber',
#  'midst sentenc accent break',
#  'might bear memori thou',
#  'might bear shun blot',
#  'might becom bettersee sad',
#  'might behold triumph face',
#  'might better use cheek',
#  'might black ink love',
#  'might buri tomb simpl',
#  'might charm thee thi',
#  'might compass fair fair',
#  'might dart injuri yet',
#  'might depart soul thi',
#  'might done ala thi',
#  'might ensu death husband',
#  'might espous fame king',
#  'might ever last bid',
#  'might excus work upon',
#  'might fortun bastard unfatherd',
#  'might insuffici heart sway',
#  'might love thou although',
#  'might make tongu tie',
#  'might master foild god',
#  'might never die riper',
#  'might noth novel noth',
#  'might o let book',
#  'might oer pressd defens',
#  'might one behold face',
#  'might open adorn dayhair',
#  'might plead justic scarlet',
#  'might rememberd deepest sens',
#  'might repos still must',
#  'might reproof reason beat',
#  'might say give full',
#  'might say love best',
#  'might see far eye',
#  'might see grave nestor',
#  'might see old world',
#  'might show far modern',
#  'might speak ill thee',
#  'might spendst thou thi',
#  'might stem wolf betray',
#  'might strain woe seem',
#  'might teach thee wit',
#  'might think sometim saw',
#  'might think untutord youth',
#  'might unus stay hand',
#  'might uphold stormi gust',
#  'might yet spread flower',
#  'mightest seat forbear chide',
#  'mighti rome th adulter',
#  'mighti thine sake leav',
#  'mightier man mightier thing',
#  'mightier thing make honourd',
#  'mightier way make war',
#  'mightili note note strongli',
#  'mighto pardon boast true',
#  'mightst thou lead away',
#  'mightst thou paus thee',
#  'mihi flavu apollo pocula',
#  'milch doe whose swell',
#  'mild continu tame one',
#  'mild glanc sli ulyss',
#  'mild grief travail faint',
#  'mild imag drew perjur',
#  'mild make young old',
#  'mild patienc seemd scorn',
#  'mild wilder tiger wildlet',
#  'mild women lose mild',
#  'mile measur thi friend',
#  'mile thou art gone',
#  'milk blood mingl togeth',
#  'million strang shadow tend',
#  'milliond accid creep twixt',
#  'mind admit impedi love',
#  'mind bodi work expir',
#  'mind brought forth thee',
#  'mind confound mutini part',
#  'mind cours alter thing',
#  'mind crownd drink monarch',
#  'mind doth debat follow',
#  'mind first charact done',
#  'mind forc never inclin',
#  'mind foul act dispens',
#  'mind frantic grief thu',
#  'mind given time dear',
#  'mind govern go doth',
#  'mind grief lie onward',
#  'mind guess measur thi',
#  'mind hand foot face',
#  'mind hang piec skil',
#  'mind ill still gaze',
#  'mind imprint bear book',
#  'mind kingli drink mine',
#  'mind like fool th',
#  'mind look unthrift world',
#  'mind love made actur',
#  'mind offic oft thou',
#  'mind part vision hold',
#  'mind proce thi wretch',
#  'mind proud femal see',
#  'mind see thou lovest',
#  'mind shall hate fairer',
#  'mind sight distractedli commixdhair',
#  'mind sinc life thi',
#  'mind take notic nigh',
#  'mind thee quiet find',
#  'mind therefor formd marbl',
#  'mind thi worst best',
#  'mind thought busi care',
#  'mind thu make mine',
#  'mind time ceas threescor',
#  'mind tongu lurk cannot',
#  'mind untaint clear joyless',
#  'mind visag littl drawn',
#  'mind wail death live',
#  'mind wakeone doth tarquin',
#  'mindeven subtl sinon paint',
#  'mindlike thievish dog creep',
#  'mindone man hand leand',
#  'mindpoor fright deer stand',
#  'mine appetit never grind',
#  'mine care art left',
#  'mine compar thou thine',
#  'mine depend feel break',
#  'mine desert hand uprear',
#  'mine desert hang prais',
#  'mine ear confound envi',
#  'mine ear let fals',
#  'mine ear love thee',
#  'mine ear tempt tune',
#  'mine ear thi tongu',
#  'mine ear wanton talk',
#  'mine enemi therefor face',
#  'mine ere pure collatino',
#  'mine excus least refug',
#  'mine eye awak mine',
#  'mine eye ball thi',
#  'mine eye behold see',
#  'mine eye best see',
#  'mine eye bless made',
#  'mine eye drawn thi',
#  'mine eye due thi',
#  'mine eye famishd look',
#  'mine eye forego light',
#  'mine eye freedom right',
#  'mine eye gray bright',
#  'mine eye grew faint',
#  'mine eye hath playd',
#  'mine eye heart guest',
#  'mine eye heart leagu',
#  'mine eye heart mortal',
#  'mine eye heart thi',
#  'mine eye interest dead',
#  'mine eye like sluic',
#  'mine eye love doth',
#  'mine eye may deceiv',
#  'mine eye mind govern',
#  'mine eye pictur angri',
#  'mine eye red fire',
#  'mine eye sad paus',
#  'mine eye saith true',
#  'mine eye see say',
#  'mine eye seen one',
#  'mine eye soul everi',
#  'mine eye sphere fit',
#  'mine eye thee thousand',
#  'mine eye true leader',
#  'mine eye turnd fire',
#  'mine eye watch tell',
#  'mine eye well know',
#  'mine eye wink shall',
#  'mine fair yet red',
#  'mine fear prophet soul',
#  'mine free reignd command',
#  'mine hardshame cri let',
#  'mine hath killd daughter',
#  'mine honour knife make',
#  'mine honour new borndear',
#  'mine honour shield experi',
#  'mine ill life foul',
#  'mine importun thee root',
#  'mine infami vain spurn',
#  'mine infamisaid shake aloft',
#  'mine lend soft audienc',
#  'mine life longer thi',
#  'mine love might o',
#  'mine love strength seem',
#  'mine make thi larg',
#  'mine mask brow hide',
#  'mine may make seem',
#  'mine mine eye true',
#  'mine mine thi good',
#  'mine must waild collatino',
#  'mine o mine repli',
#  'mine offenc constraind dread',
#  'mine pour ocean among',
#  'mine prais mine self',
#  'mine prais thee even',
#  'mine ransom must ransom',
#  'mine region cloud hath',
#  'mine repli husband take',
#  'mine restorplenitud subtl matter',
#  'mine reveng made stop',
#  'mine robbd other bed',
#  'mine seest thou ground',
#  'mine self bring mine',
#  'mine self love quit',
#  'mine shall sum count',
#  'mine shape true truth',
#  'mine slain thou gavest',
#  'mine suppos thou dost',
#  'mine thi good report',
#  'mine thi love thi',
#  'mine thine even first',
#  'mine thine shall prais',
#  'mine thine thou hadst',
#  'mine thou hast depriv',
#  'mine thou wilt restor',
#  'mine thought sold cheap',
#  'mine ti meritori fair',
#  'mine true love doth',
#  'mine weak best acquaint',
#  'mine worth defin worth',
#  'mine would goodtell girl',
#  'minedone quoth uncontrol tide',
#  'minethu forestal thee thou',
#  'mingl beauti infirm pure',
#  'mingl blush red guilti',
#  'mingl hot scent snuf',
#  'mingl talk tear grief',
#  'mingl togeth second fear',
#  'minion pleasur may detain',
#  'minist obey work audit',
#  'ministret aquaright honor henri',
#  'minor right yet ambit',
#  'minstrel tune defam tie',
#  'minut age would purchas',
#  'minut fight bring beauti',
#  'minut fill hour captain',
#  'minut hasten end chang',
#  'minut hour wherein kiss',
#  'minut kill yet fear',
#  'minut mirth wail week',
#  'minut pay hour debtquoth',
#  'minut tell point thunder',
#  'minut wast vacant leav',
#  'miracl labor wit nremembr',
#  'miracl might black ink',
#  'mire unperceiv fli filth',
#  'miretur vulgu mihi flavu',
#  'mirror dim old show',
#  'mirth doth search bottom',
#  'mirth wail week sell',
#  'miscalld simplic captiv good',
#  'mischanc cross tarquin flight',
#  'mischanc make moan piti',
#  'mischanc much miseri burn',
#  'mischief thi pilgrimag unless',
#  'mischief wors civil home',
#  'misde askanc eyethee thee',
#  'misde cannot hid claydeed',
#  'miser wealth found proud',
#  'miseri burn fever agu',
#  'miseri trodden mani low',
#  'misfortun carv tear quoth',
#  'misgovern seek stain ocean',
#  'mishap poor bird helpless',
#  'misl give watch word',
#  'misplac maiden virtu rude',
#  'mispris grow come home',
#  'miss follow murder kisseven',
#  'miss seek kindl continu',
#  'missd littl star may',
#  'missd poor retent could',
#  'mist aspir mountain hide',
#  'mist meet eastern light',
#  'mist thi dote eyn',
#  'mistak aim cleav infant',
#  'mistak brain troubltongu cannot',
#  'mistak smell sometim earth',
#  'mistak thi great gift',
#  'mistak view sun see',
#  'misti night cover shame',
#  'misti vapour blot sky',
#  'misti vapour march thick',
#  'mistook matter slay slain',
#  'mistress brow raven black',
#  'mistress eye love brand',
#  'mistress eye noth like',
#  'mistress fate trespass never',
#  'mistress heart woeful self',
#  'mistress hie fleet wingd',
#  'mistress mount empti sky',
#  'mistress ornament chastpoor forbid',
#  'mistress passion woman gentl',
#  'mistress reek love hear',
#  'mistress sky salt wave',
#  'mistress thrall came cure',
#  'mistress walk tread ground',
#  'mistress wrack thou goest',
#  'mistrust fals creep craft',
#  'mistrust servitor unjust cross',
#  'mistrust shall merci sever',
#  'mistrust two red fire',
#  'mistrust wood even confound',
#  'misus thee honest faith',
#  'mixd cloud brow repin',
#  'mixd oratori add grace',
#  'mixd second know art',
#  'moan expens mani vanishd',
#  'moan mad sweet melodi',
#  'moan merit respect proud',
#  'moan move tear sigh',
#  'moan new pay paid',
#  'moan passion passion deepli',
#  'moan piti moan stone',
#  'moan plaint littl doth',
#  'moan receiv nought element',
#  'moan stone hardend heart',
#  'moan tire moan plaint',
#  'moanlo trophi affect hot',
#  'moano night thou furnac',
#  'mock mindone man hand',
#  'mock presag incertainti crown',
#  'mock resort let time',
#  'mock sight thi spirit',
#  'mock subtl beguil cheer',
#  'mock thi tickl beam',
#  'modern quill doth come',
#  'modest dian cloudi forlorn',
#  'modest eloqu sigh mixd',
#  'modest eye sorrow shed',
#  'modest lucrec wore night',
#  'modest pride anon rear',
#  'modest snow white weedo',
#  'modest wanton wanton modesti',
#  'modesti encampd heart fight',
#  'modesti hot wrath fire',
#  'modesti show life triumph',
#  'modesti sort sad look',
#  'modestli prepar let know',
#  'moe let sin alon',
#  'moe letter sadli pennd',
#  'moe pleasur bestow true',
#  'moe woe word depend',
#  'moieti dear heart part',
#  'moieti nthe warrant honour',
#  'moist cabinet mount high',
#  'moist hand thi hand',
#  'moistend like melt eye',
#  'moistur air grace wish',
#  'moistur eye o fals',
#  'moistur sweet coral mouth',
#  'moment callunruli blast wait',
#  'moment doth confound kill',
#  'moment forc subdu would',
#  'moment huge stage presenteth',
#  'momentari joy breed month',
#  'monarch hand let bounti',
#  'monarch plagu flatteri whether',
#  'monarch still feard love',
#  'monarchilook tribut wound fanci',
#  'monster thing indigest cherubin',
#  'month pain hot desir',
#  'monument feed oblivion decay',
#  'monument last moano night',
#  'monument lie admir lewd',
#  'monument princ shall outliv',
#  'monument shall gentl vers',
#  'monument tyrant crest tomb',
#  'mood effect terror dear',
#  'mood frown wrinkl strang',
#  'mood nought agre old',
#  'mood tear could help',
#  'moodi heavi tell thi',
#  'moodi pluto wink orpheu',
#  'moon cloud present missd',
#  'moon earth sea rich',
#  'moon hath eclips endur',
#  'moon sun loathsom canker',
#  'moon water seen nighto',
#  'moonlook fair fieri point',
#  'moral appli love comment',
#  'moral wanton sight eye',
#  'morn air let exhal',
#  'morn earth relieveth bright',
#  'morn ever yet betokend',
#  'morn hath travelld age',
#  'morn joy make moan',
#  'morn light pray never',
#  'morn much oerworn yet',
#  'morn rose cheekd adoni',
#  'morn seen flatter mountain',
#  'morn sentinel night wrong',
#  'morn shine triumphant splendor',
#  'morn silver melt dew',
#  'morn sun heaven better',
#  'morn till night even',
#  'morn weari even delight',
#  'morn whose silver breast',
#  'morrow intend hunt boar',
#  'morrow kind still constant',
#  'morrow lend light fair',
#  'morrow linger purpos overthrow',
#  'morrow o thou clear',
#  'morrow say shall shall',
#  'morrow see kill spirit',
#  'morrow sharpend former might',
#  'morrow soft slow tongu',
#  'morrow think long remain',
#  'morrowthou need wilt hunt',
#  'mortal butcher bent killbow',
#  'mortal eye comfort star',
#  'mortal fault brought subject',
#  'mortal kind dead beauti',
#  'mortal look ador beauti',
#  'mortal moon hath eclips',
#  'mortal oer sway power',
#  'mortal pitch struck dead',
#  'mortal rage seen hungri',
#  'mortal round would thou',
#  'mortal sleep beautifi twain',
#  'mortal star bright heaven',
#  'mortal stingchamber wickedli stalk',
#  'mortal thingquoth sweet death',
#  'mortal vigour sinc best',
#  'mortal war divid conquest',
#  'mortgag thi ill forfeit',
#  'mot afar peac wound',
#  'mote peep though men',
#  'mother born hard mind',
#  'mother child though bright',
#  'mother dread fear upon',
#  'mother fair whose uneard',
#  'mother glass thee call',
#  'mother groan respect swell',
#  'mother may lend thee',
#  'mother one one pleas',
#  'mother part kiss kind',
#  'mother share joy see',
#  'mother tri merciless conclus',
#  'motion doth behold everi',
#  'motion mine eye may',
#  'motion seem owe would',
#  'motion shall know hors',
#  'motion slide quicker element',
#  'motion sound thi sweet',
#  'motion stone dissolv water',
#  'motion thine eye love',
#  'motiv woeslide upon grain',
#  'motley view gore mine',
#  'mould heaven divin wherein',
#  'mount die insult falchion',
#  'mount empti sky light',
#  'mount high wake morn',
#  'mount hot encount imaginari',
#  'mount wind wing speed',
#  'mount wors tantalu annoy',
#  'mountain dale graze lip',
#  'mountain hide earth dark',
#  'mountain sea day night',
#  'mountain snow melt midday',
#  'mountain spring feed dale',
#  'mountain top sovereign eye',
#  'mourn becom woe everi',
#  'mourn black round tear',
#  'mourn dead shall hear',
#  'mourn doth thee grace',
#  'mourn eye becom thi',
#  'mourn habit demand caus',
#  'mourn hymn hush night',
#  'mourn newer waylast call',
#  'mourn sinc mourn doth',
#  'mourner black grim welkin',
#  'mourner look pretti ruth',
#  'mourner say weep mine',
#  'mourner seem born fair',
#  'mous panteth sad behavior',
#  'mouth back breastsee true',
#  'mouth bepaint red like',
#  'mouth echo repli anoth',
#  'mouth grave give thee',
#  'mouth swallow venu like',
#  'mouth whose preciou tast',
#  'mouthd mourner black grim',
#  'move bewitch like wanton',
#  'move hear told eye',
#  'move one consent gener',
#  'move other stone unmov',
#  'move part sensibl though',
#  'move point gracious fair',
#  'move rage lesser piti',
#  'move still thee sleep',
#  'move storm oft twixt',
#  'move strike whateer way',
#  'move tear sigh groantogeth',
#  'move thi piti ball',
#  'move woman moan move',
#  'mover mortal round would',
#  'mow yet time hope',
#  'much ado cold fault',
#  'much amaz break ope',
#  'much borrow owe love',
#  'much clearer light unse',
#  'much disdain lest sorrow',
#  'much doth beauti beauteou',
#  'much earth water wrought',
#  'much enrich thi book',
#  'much fair death conquest',
#  'much fool weak silli',
#  'much glori gainer bend',
#  'much great love keep',
#  'much grief tongupoor instrument',
#  'much guil would said',
#  'much handl fleet foot',
#  'much hold need talli',
#  'much labour drown want',
#  'much less shame remain',
#  'much like press peopl',
#  'much liker paint counterfeit',
#  'much may prove plead',
#  'much miseri burn fever',
#  'much oerworn yet hear',
#  'much outliv gild tomb',
#  'much pineth stillnever cope',
#  'much poor name rehears',
#  'much prais deserv thi',
#  'much profan wrong hapli',
#  'much rage whose strength',
#  'much rent compound sweet',
#  'much reproach containamong mani',
#  'much steal men eye',
#  'much stillitori thi face',
#  'much talk affordlittl bird',
#  'much torment us defect',
#  'much vers sit glass',
#  'much warmd affect put',
#  'much wonder eye could',
#  'mud cloud eclips stain',
#  'mud found yet moe',
#  'mud fountain gave drink',
#  'mud tyrant folli lurk',
#  'muffl bawd dark harbour',
#  'mulberri ripe red cherri',
#  'murder bloodi full blame',
#  'murder contrari roman law',
#  'murder fell vast sin',
#  'murder hate gainst thyself',
#  'murder kisseven empti eagl',
#  'murder knife left place',
#  'murder rage thi heinou',
#  'murder shame scorn shame',
#  'murder straight ill slaughter',
#  'murder theft guilti perjuri',
#  'murder wake stain killlust',
#  'murderd poor heart mine',
#  'murderd view like star',
#  'murderst o hear injuri',
#  'murderst troth thou foul',
#  'murmur stay miseri trodden',
#  'murtherthousand spleen bear thousand',
#  'muse bring forth scope',
#  'muse doth give anoth',
#  'muse file think good',
#  'muse found fair assist',
#  'muse grown grow age',
#  'muse love sweet face',
#  'muse manner hold still',
#  'muse morn much oerworn',
#  'muse pleas curiou day',
#  'muse shall thi amend',
#  'muse stirrd paint beauti',
#  'muse straight redeem gentl',
#  'muse teach thee make',
#  'muse ten time worth',
#  'muse therefor mayst without',
#  'muse thou forgetst long',
#  'muse want subject invent',
#  'muse wilt thou hapli',
#  'muset goe like labyrinth',
#  'music burthen everi bough',
#  'music canst thou boast',
#  'music hath far pleas',
#  'music hear hearst thou',
#  'music heart deep sore',
#  'music music playst upon',
#  'music playst upon bless',
#  'music sadli sweet sweet',
#  'must abid mark thee',
#  'must assay forc exampl',
#  'must attend time leisur',
#  'must bear thee like',
#  'must burn o piti',
#  'must confess kiss killd',
#  'must confess raild thee',
#  'must coold els sufferd',
#  'must curb upon other',
#  'must day say oer',
#  'must deflow power pray',
#  'must die earth yield',
#  'must die till mutual',
#  'must dote tarquin make',
#  'must enjoy thee thou',
#  'must expir consum nourishd',
#  'must forc desirpale fear',
#  'must forsak truth self',
#  'must go sinc sweet',
#  'must leav ere long',
#  'must live drawn sweet',
#  'must lode star lust',
#  'must miracl labor wit',
#  'must neer love thou',
#  'must noth hold pleas',
#  'must oblat sinc altar',
#  'must ope bless leagu',
#  'must quietu render thee',
#  'must removay quoth venu',
#  'must render origin ender',
#  'must repel lover though',
#  'must see skill find',
#  'must sell joy life',
#  'must shown unless gener',
#  'must sit pine season',
#  'must soul bark peeld',
#  'must strive know shame',
#  'must sweet thief sourli',
#  'must thee read lectur',
#  'must thi cruel eye',
#  'must thou destroy dark',
#  'must tombd thee use',
#  'must took thu pine',
#  'must transgress bow unless',
#  'must twain although undivid',
#  'must use read thi',
#  'must victori us congest',
#  'must vomit receipt ere',
#  'must waild collatino quoth',
#  'must work way thi',
#  'muster thi mist meet',
#  'muster troop care ask',
#  'mute client break desper',
#  'mute dumb restless discord',
#  'mute frail joint shake',
#  'mute give one kiss',
#  'mute other would give',
#  'mute sing ti dull',
#  'mutini live die twain',
#  'mutini part doth surpris',
#  'mutini peac hour doth',
#  'mutini restrain unto greater',
#  'mutual order resembl sire',
#  'mutual overthrow mortal kind',
#  'mutual render thee henc',
#  'myrtl grove muse morn',
#  ...]
